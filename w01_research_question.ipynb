# %% [markdown]
# <a href="https://colab.research.google.com/github/ashoktanakanti/flyrank_ml/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ashoktanakanti/flyrank_ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I am choosing the Decline Recovery Classification lane. I chose this because predicting which clients or content pieces are on the verge of a structural drop allows the business to be proactive rather than reactive. Identifying early signals shifts the focus from simply reporting past metrics to preserving revenue and preventing churn before it happens.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Setting up the environment for the notebook
# !pip install -q datasets pandas
import pandas as pd
from datasets import load_dataset
print("Environment ready.")
# Out:
# Environment ready.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The Decision: Determining whether to allocate human review or targeted marketing resources to a specific client.
#
# The Action: Flagging the client for an immediate "refresh" queue or automated intervention campaign.
#
# The Cost of a Wrong Call:
#
# False Positive (Flagging a healthy client): Wasted operational bandwidth and unnecessary review costs.
#
# False Negative (Missing a real decline): Loss of the client, unrecoverable metric drops, and structural churn.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Defining the impact scope variables for future reference
false_positive_cost = "Wasted operational bandwidth"
false_negative_cost = "Client churn"
print(f"Optimizing to avoid: {false_negative_cost}")
# Out:
# Optimizing to avoid: Client churn

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Loading the dim_clients table from the FlyRank Hugging Face warehouse to establish the baseline volume of our entities and the overall completeness of the dataset we have to work with.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Load the dim_clients split from the Hugging Face FlyRank warehouse
print("Loading FlyRank dim_clients dataset...")

# Authenticate with Hugging Face Hub to access gated dataset.
# You will be prompted to enter your Hugging Face token.
# Get a token here: https://huggingface.co/settings/tokens
from huggingface_hub import notebook_login
notebook_login()

dataset = load_dataset("FlyRank/internship-warehouse", "dim_clients", split="train")

# Convert to pandas for quick EDA
df_clients = dataset.to_pandas()

# Calculate 3 real numbers
total_clients = len(df_clients)
total_features = len(df_clients.columns)
missing_values = df_clients.isna().sum().sum()

print(f"Number 1: Total Client Records available for analysis: {total_clients}")
print(f"Number 2: Total distinct features (columns) per client: {total_features}")
print(f"Number 3: Total missing data points across the table: {missing_values}")
# Out:
# Loading FlyRank dim_clients dataset...
# Number 1: Total Client Records available for analysis: 104
# Number 2: Total distinct features (columns) per client: 9
# Number 3: Total missing data points across the table: 140

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can claim: I can provide observed, directional decision-support based on historical correlations between early-stage metrics and eventual structural declines.
#
# What I cannot claim: I cannot claim causal proof (e.g., asserting that a specific Google algorithm update caused a drop), nor can I perfectly predict future Google Search Console performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Final validation check
print("Data loaded, framing complete, and claims defined. Ready for EDA.")
# Out:
# Data loaded, framing complete, and claims defined. Ready for EDA.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
